# %% [markdown]
# # Install Libraries

# %%
pip install pandas sqlalchemy oracledb datetime
# Out:
# Requirement already satisfied: pandas in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: sqlalchemy in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (2.0.40)
# Requirement already satisfied: oracledb in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (3.1.0)
# Requirement already satisfied: datetime in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (5.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: greenlet>=1 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: cryptography>=3.2.1 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from oracledb) (44.0.2)
# Requirement already satisfied: zope.interface in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from datetime) (7.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.2.1->oracledb) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: setuptools in c:\users\yashv\appdata\local\programs\python\python313\lib\site-packages (from zope.interface->datetime) (79.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Extract Data from Kaggle CSV (dataset) -- EXTRACTION

# %%
import kaggle
kaggle.api.authenticate()
kaggle.api.dataset_download_files('youvolvedata/employee-salary-data', path = 'C:/Users/yashv/Desktop/Employee_salary_data_project', unzip = True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/youvolvedata/employee-salary-data

# %% [markdown]
# ### Import dataset to dataframe

# %%
import pandas as pd

#Loading the dataset
df = pd.read_csv("C:/Users/yashv/Desktop/Employee_salary_data_project/emp_salary_data.csv")
df.head()
# Out:
#   emp id first name last name                  department    join date  \
# 0  CU025    Aubr#ey     Clark  Customer Support & Service   4-Jan-2012
# 1  CU026    Preston     Clark  Customer Support & Service   4-Jan-2012
# 2  CU031  Josephine    Meyers  Customer Support & Service   5-Jan-2012
# 3  CU041      Irene      Ward  Customer Support & Service  14-Jan-2012
# 4  CU050      Faith  Gonzales  Customer Support & Service  19-Jan-2012
#
#   monthly salary   birth date
# 0           6700  29-Mar-1956
# 1           6700  12-Apr-1956
# 2           6900   5-Nov-1989
# 3           6600  20-Sep-1960
# 4           6500  21-Oct-1961

# %%
df['department'].unique()        #finding unique departments
# Out:
# array(['Customer Support & Service', nan, 'Finance & Accounting',
#        'Human Resources', 'Information Technology', 'Legal & Compliance',
#        'Manufacturing & Production', 'Quality Assurance & Control',
#        'Research & Development', 'Sales & Marketing'], dtype=object)

# %%
df['first_name'] = df['first name'].str.isalpha()       #finding errors in first name 
df['last_name'] = df['last name'].str.isalpha()         #finding errors in last name
df['monthly_salary'] = df['monthly salary'].str.isnumeric()  #finding errors in monthly salary

# %% [markdown]
# # Transformation on data begins

# %% [markdown]
# ### Rows with alphanumeric data issues

# %%
df2 = df.query('first_name == False or last_name == False or monthly_salary ==False')
df2
# Out:
#     emp id  first name  last name                  department    join date  \
# 0    CU025     Aubr#ey      Clark  Customer Support & Service   4-Jan-2012
# 39   CU335      Selena      James  Customer Support & Service  11-May-2020
# 183  IN185       Isaac  Peter+son      Information Technology  28-Mar-2016
# 232  LE280  Pris$cilla      Lewis          Legal & Compliance  11-Feb-2019
# 261  LE511       Betty    Ada$$ms          Legal & Compliance  21-Dec-2024
# 299  MA215      Claire    Bennett  Manufacturing & Production  22-Nov-2017
# 365  MA525     Gilbert       Cruz  Manufacturing & Production  29-Dec-2024
#
#     monthly salary   birth date  first_name  last_name monthly_salary
# 0             6700  29-Mar-1956       False       True           True
# 39           6&500  29-Mar-1950        True       True          False
# 183           9600   2-Jan-1966        True      False           True
# 232          10900  16-Jan-1955       False       True           True
# 261          10700   7-Sep-1957        True      False           True
# 299          9 300   1-Jan-1950        True       True          False
# 365          73 00  15-Feb-1950        True       True          False

# %% [markdown]
# ### Modifying data issues

# %%
df['first name'] = df['first name'].str.replace('#','')
df['first name'] = df['first name'].str.replace('$','')
df['last name'] = df['last name'].str.replace('+','')
df['last name'] = df['last name'].str.replace('$','')
df['monthly salary'] = df['monthly salary'].str.replace('&','')
df['monthly salary'] = df['monthly salary'].str.replace(' ','')

# %%
df.drop(['first_name', 'last_name', 'monthly_salary'], axis =1, inplace=True)

# %% [markdown]
# ### Rows with alphanumeric data issue -- fixed

# %%
df
# Out:
#     emp id first name  last name                  department    join date  \
# 0    CU025     Aubrey      Clark  Customer Support & Service   4-Jan-2012
# 1    CU026    Preston      Clark  Customer Support & Service   4-Jan-2012
# 2    CU031  Josephine     Meyers  Customer Support & Service   5-Jan-2012
# 3    CU041      Irene       Ward  Customer Support & Service  14-Jan-2012
# 4    CU050      Faith   Gonzales  Customer Support & Service  19-Jan-2012
# ..     ...        ...        ...                         ...          ...
# 520  SA513   Emmanuel  Henderson           Sales & Marketing  21-Dec-2024
# 521  SA520    Vincent     Parker           Sales & Marketing  21-Dec-2024
# 522  SA523      Clara       Wood           Sales & Marketing  29-Dec-2024
# 523  SA528     Krista     Powell           Sales & Marketing  29-Dec-2024
# 524  SA530     Sherri       Wood           Sales & Marketing  29-Dec-2024
#
#     monthly salary   birth date
# 0             6700  29-Mar-1956
# 1             6700  12-Apr-1956
# 2             6900   5-Nov-1989
# 3             6600  20-Sep-1960
# 4             6500  21-Oct-1961
# ..             ...          ...
# 520          10200  14-Mar-1961
# 521          10200  28-Apr-1961
# 522          10300   5-Nov-1959
# 523          10100  29-Mar-1962
# 524          10300  19-Dec-1959
#
# [525 rows x 7 columns]

# %% [markdown]
# ### Checing join date dataype

# %%
df['join date2'] = df['join date']
df['join date'] = pd.to_datetime(df['join date'], format = "%d-%b-%Y", errors = 'coerce')

# %% [markdown]
# ### data with invalid date datatype in join date

# %%
df3 = df[df['join date'].isna()]
df3
# Out:
#     emp id first name  last name                   department join date  \
# 50   CU534       Fred     Graham   Customer Support & Service       NaT
# 51   CU541     Wilson     Brooks   Customer Support & Service       NaT
# 52   CU545     Janice       Long   Customer Support & Service       NaT
# 104  FI535        Ida        Cox         Finance & Accounting       NaT
# 105  FI546      Julia   Mitchell         Finance & Accounting       NaT
# 208  IN533     Donald      Ellis       Information Technology       NaT
# 209  IN538    Lindsay     Brewer       Information Technology       NaT
# 210  IN540       Toby      Ellis       Information Technology       NaT
# 211  IN544   Gretchen     Meyers       Information Technology       NaT
# 366  MA536    Jillian     Fisher   Manufacturing & Production       NaT
# 367  MA542   Courtney  Patterson   Manufacturing & Production       NaT
# 368  MA547      Lacey   Gonzales   Manufacturing & Production       NaT
# 369  MA548    Stanley  Patterson   Manufacturing & Production       NaT
# 416  QU532  Catherine     Howard  Quality Assurance & Control       NaT
# 417  QU537     Kelvin     Watson  Quality Assurance & Control       NaT
# 418  QU539     Samuel     Howard  Quality Assurance & Control       NaT
# 419  QU543      Emery       Wood  Quality Assurance & Control       NaT
# 420  QU549   Veronica    Roberts  Quality Assurance & Control       NaT
#
#     monthly salary   birth date   join date2
# 50            6600  24-Aug-1961  31-Nov-2017
# 51            6600   7-Sep-1961  31-Jun-2017
# 52            6700   6-Aug-1960  29-Feb-2015
# 104           7700  19-Dec-1983  31-Nov-2017
# 105           7600   6-Aug-1984  29-Feb-2015
# 208           9500  10-Jul-1967  31-Nov-2016
# 209           9600  23-Jul-1966  31-Jun-2015
# 210           9500  24-Aug-1967  31-Nov-2017
# 211           9600   6-Aug-1966  31-Sep-2015
# 366           9300  28-Apr-1969  31-Nov-2017
# 367           9400  12-Apr-1968  31-Apr-2015
# 368           9200  15-Feb-1970  31-Feb-2015
# 369           9400  26-May-1968  31-Sep-2015
# 416           8000  23-Jul-1980  31-Nov-2017
# 417           8200   4-Oct-1978  31-Nov-2017
# 418           8000   6-Aug-1980  29-Feb-2017
# 419           8100  10-Jul-1979  31-Sep-2015
# 420           8100  24-Aug-1979  31-Sep-2015

# %%
df.drop('join date2', axis = 1, inplace=True)

# %%
df
# Out:
#     emp id first name  last name                  department  join date  \
# 0    CU025     Aubrey      Clark  Customer Support & Service 2012-01-04
# 1    CU026    Preston      Clark  Customer Support & Service 2012-01-04
# 2    CU031  Josephine     Meyers  Customer Support & Service 2012-01-05
# 3    CU041      Irene       Ward  Customer Support & Service 2012-01-14
# 4    CU050      Faith   Gonzales  Customer Support & Service 2012-01-19
# ..     ...        ...        ...                         ...        ...
# 520  SA513   Emmanuel  Henderson           Sales & Marketing 2024-12-21
# 521  SA520    Vincent     Parker           Sales & Marketing 2024-12-21
# 522  SA523      Clara       Wood           Sales & Marketing 2024-12-29
# 523  SA528     Krista     Powell           Sales & Marketing 2024-12-29
# 524  SA530     Sherri       Wood           Sales & Marketing 2024-12-29
#
#     monthly salary   birth date
# 0             6700  29-Mar-1956
# 1             6700  12-Apr-1956
# 2             6900   5-Nov-1989
# 3             6600  20-Sep-1960
# 4             6500  21-Oct-1961
# ..             ...          ...
# 520          10200  14-Mar-1961
# 521          10200  28-Apr-1961
# 522          10300   5-Nov-1959
# 523          10100  29-Mar-1962
# 524          10300  19-Dec-1959
#
# [525 rows x 7 columns]

# %%
df = df.dropna()

# %%
df    #dropped null values
# Out:
#     emp id first name  last name                  department  join date  \
# 0    CU025     Aubrey      Clark  Customer Support & Service 2012-01-04
# 1    CU026    Preston      Clark  Customer Support & Service 2012-01-04
# 2    CU031  Josephine     Meyers  Customer Support & Service 2012-01-05
# 3    CU041      Irene       Ward  Customer Support & Service 2012-01-14
# 4    CU050      Faith   Gonzales  Customer Support & Service 2012-01-19
# ..     ...        ...        ...                         ...        ...
# 520  SA513   Emmanuel  Henderson           Sales & Marketing 2024-12-21
# 521  SA520    Vincent     Parker           Sales & Marketing 2024-12-21
# 522  SA523      Clara       Wood           Sales & Marketing 2024-12-29
# 523  SA528     Krista     Powell           Sales & Marketing 2024-12-29
# 524  SA530     Sherri       Wood           Sales & Marketing 2024-12-29
#
#     monthly salary   birth date
# 0             6700  29-Mar-1956
# 1             6700  12-Apr-1956
# 2             6900   5-Nov-1989
# 3             6600  20-Sep-1960
# 4             6500  21-Oct-1961
# ..             ...          ...
# 520          10200  14-Mar-1961
# 521          10200  28-Apr-1961
# 522          10300   5-Nov-1959
# 523          10100  29-Mar-1962
# 524          10300  19-Dec-1959
#
# [505 rows x 7 columns]

# %% [markdown]
# ### Fix the column header space

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df = df.copy()
df['birth_date'] = pd.to_datetime(df['birth_date'], format='%d-%b-%Y')

# %% [markdown]
# # Loading the cleaned dataset to the Oracle database using Oralcedb and SQLAlchemy

# %% [markdown]
# ###  Connect to Oracle Database using oracledb + sqlalchemy

# %%
import sqlalchemy as odb

# %%
username = 'THIS_PC'
password = 'thispcpassword'
dsn = 'localhost:1521/?service_name=xepdb1'
conn_str = 'oracle+oracledb://'+username+':'+password+'@'+dsn
print(conn_str)
eng = odb.create_engine(conn_str)
df.to_sql('employee_salary_data', con= eng, if_exists='append', index = False)
# Out:
# oracle+oracledb://THIS_PC:thispcpassword@localhost:1521/?service_name=xepdb1
# -1

# %%
# Save query result to CSV file
df.to_csv('C:/Users/yashv/Desktop/Employee_salary_data_project/src/datasets/cleaned_dataset.csv', index=False)

print("Exported cleaned data successfully!")
# Out:
# Exported cleaned data successfully!
